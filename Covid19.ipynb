# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
pwd
# Out:
# 'C:\\Users\\rk987'

# %%
dataset = pd.read_csv(r"C:/Users/rk987/OneDrive/Desktop/covid19_Confirmed_dataset.csv")
dataset
# Out:
#     Province/State         Country/Region        Lat       Long  1/22/20  \
# 0              NaN            Afghanistan  33.000000  65.000000        0
# 1              NaN                Albania  41.153300  20.168300        0
# 2              NaN                Algeria  28.033900   1.659600        0
# 3              NaN                Andorra  42.506300   1.521800        0
# 4              NaN                 Angola -11.202700  17.873900        0
# ..             ...                    ...        ...        ...      ...
# 261            NaN         Western Sahara  24.215500 -12.885800        0
# 262            NaN  Sao Tome and Principe   0.186360   6.613081        0
# 263            NaN                  Yemen  15.552727  48.516388        0
# 264            NaN                Comoros -11.645500  43.333300        0
# 265            NaN             Tajikistan  38.861034  71.276093        0
#
#      1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  ...  4/21/20  4/22/20  \
# ...

# %%
dataset.shape
# Out:
# (266, 104)

# %%
df = dataset.drop(["Lat","Long"], axis=1,inplace=True)

# %%
dataset.head()
# Out:
#   Province/State Country/Region  1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  \
# 0            NaN    Afghanistan        0        0        0        0        0
# 1            NaN        Albania        0        0        0        0        0
# 2            NaN        Algeria        0        0        0        0        0
# 3            NaN        Andorra        0        0        0        0        0
# 4            NaN         Angola        0        0        0        0        0
#
#    1/27/20  1/28/20  1/29/20  ...  4/21/20  4/22/20  4/23/20  4/24/20  \
# 0        0        0        0  ...     1092     1176     1279     1351
# 1        0        0        0  ...      609      634      663      678
# 2        0        0        0  ...     2811     2910     3007     3127
# 3        0        0        0  ...      717      723      723      731
# 4        0        0        0  ...       24       25       25       25
#
#    4/25/20  4/26/20  4/27/20  4/28/20  4/29/20  4/30/20
# ...

# %%
aggregate = dataset.groupby("Country/Region").sum()
# Out:
# C:\Users\rk987\AppData\Local\Temp\ipykernel_11460\386069218.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   aggregate = dataset.groupby("Country/Region").sum()

# %%
aggregate.head()
# Out:
#                 1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  1/28/20  \
# Country/Region
# Afghanistan           0        0        0        0        0        0        0
# Albania               0        0        0        0        0        0        0
# Algeria               0        0        0        0        0        0        0
# Andorra               0        0        0        0        0        0        0
# Angola                0        0        0        0        0        0        0
#
#                 1/29/20  1/30/20  1/31/20  ...  4/21/20  4/22/20  4/23/20  \
# Country/Region                             ...
# Afghanistan           0        0        0  ...     1092     1176     1279
# Albania               0        0        0  ...      609      634      663
# Algeria               0        0        0  ...     2811     2910     3007
# Andorra               0        0        0  ...      717      723      723
# ...

# %%
aggregate.shape
# Out:
# (187, 100)

# %%
aggregate.loc["China"].plot()
aggregate.loc["India"].plot()
aggregate.loc["Afghanistan"].plot()
plt.legend()

# %%
aggregate.loc["China"][:5].plot()
# Out:
# <Axes: >

# %%
aggregate.loc["India"].diff().plot()
# Out:
# <Axes: >

# %%
aggregate.loc["India"].diff().max()
# Out:
# 1893.0

# %%
countries=list(aggregate.index)
max_infected_counts=[]
for c in countries:
       max_infected_counts.append(aggregate.loc[c].diff().max())
aggregate["max_infected_counts"]=max_infected_counts

# %%
aggregate
# Out:
#                     1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  \
# Country/Region
# Afghanistan               0        0        0        0        0        0
# Albania                   0        0        0        0        0        0
# Algeria                   0        0        0        0        0        0
# Andorra                   0        0        0        0        0        0
# Angola                    0        0        0        0        0        0
# ...                     ...      ...      ...      ...      ...      ...
# West Bank and Gaza        0        0        0        0        0        0
# Western Sahara            0        0        0        0        0        0
# Yemen                     0        0        0        0        0        0
# Zambia                    0        0        0        0        0        0
# Zimbabwe                  0        0        0        0        0        0
#
# ...

# %%
new_corona_data= pd.DataFrame(aggregate["max_infected_counts"])

# %%
new_corona_data
# Out:
#                     max_infected_counts
# Country/Region
# Afghanistan                       232.0
# Albania                            34.0
# Algeria                           199.0
# Andorra                            43.0
# Angola                              5.0
# ...                                 ...
# West Bank and Gaza                 66.0
# Western Sahara                      4.0
# Yemen                               5.0
# Zambia                              9.0
# Zimbabwe                            8.0
#
# [187 rows x 1 columns]

# %%
happiness = pd.read_csv(r"C:/Users/rk987/OneDrive/Desktop/worldwide_happiness_report.csv")

# %%
happiness.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# 3                    1.026                         0.591       0.354
# 4                    0.999                         0.557       0.322
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.410
# ...

# %%
useless_columns = ["Overall rank","Score","Generosity","Perceptions of corruption"]

# %%
new_happiness = happiness.drop(useless_columns, axis=1, inplace=True)

# %%
happiness.head()
# Out:
#   Country or region  GDP per capita  Social support  Healthy life expectancy  \
# 0           Finland           1.340           1.587                    0.986
# 1           Denmark           1.383           1.573                    0.996
# 2            Norway           1.488           1.582                    1.028
# 3           Iceland           1.380           1.624                    1.026
# 4       Netherlands           1.396           1.522                    0.999
#
#    Freedom to make life choices
# 0                         0.596
# 1                         0.592
# 2                         0.603
# 3                         0.591
# 4                         0.557

# %%
happiness.set_index("Country or region", inplace=True)
happiness.head()
# Out:
#                    GDP per capita  Social support  Healthy life expectancy  \
# Country or region
# Finland                     1.340           1.587                    0.986
# Denmark                     1.383           1.573                    0.996
# Norway                      1.488           1.582                    1.028
# Iceland                     1.380           1.624                    1.026
# Netherlands                 1.396           1.522                    0.999
#
#                    Freedom to make life choices
# Country or region
# Finland                                   0.596
# Denmark                                   0.592
# Norway                                    0.603
# Iceland                                   0.591
# Netherlands                               0.557

# %%
new_corona_data.shape
# Out:
# (187, 1)

# %%
happiness.shape
# Out:
# (156, 4)

# %%
data = new_corona_data.join(happiness, how="inner")
data.shape
# Out:
# (143, 5)

# %%
data.corr()
# Out:
#                               max_infected_counts  GDP per capita  \
# max_infected_counts                      1.000000        0.250118
# GDP per capita                           0.250118        1.000000
# Social support                           0.191958        0.759468
# Healthy life expectancy                  0.289263        0.863062
# Freedom to make life choices             0.078196        0.394603
#
#                               Social support  Healthy life expectancy  \
# max_infected_counts                 0.191958                 0.289263
# GDP per capita                      0.759468                 0.863062
# Social support                      1.000000                 0.765286
# Healthy life expectancy             0.765286                 1.000000
# Freedom to make life choices        0.456246                 0.427892
#
#                               Freedom to make life choices
# max_infected_counts                               0.078196
# ...

# %%
data
# Out:
#              max_infected_counts  GDP per capita  Social support  \
# Afghanistan                232.0           0.350           0.517
# Albania                     34.0           0.947           0.848
# Algeria                    199.0           1.002           1.160
# Argentina                  291.0           1.092           1.432
# Armenia                    134.0           0.850           1.055
# ...                          ...             ...             ...
# Venezuela                   29.0           0.960           1.427
# Vietnam                     19.0           0.741           1.346
# Yemen                        5.0           0.287           1.163
# Zambia                       9.0           0.578           1.058
# Zimbabwe                     8.0           0.366           1.114
#
#              Healthy life expectancy  Freedom to make life choices
# Afghanistan                    0.361                         0.000
# ...

# %%
data
# Out:
#              max_infected_counts  GDP per capita  Social support  \
# Afghanistan                232.0           0.350           0.517
# Albania                     34.0           0.947           0.848
# Algeria                    199.0           1.002           1.160
# Argentina                  291.0           1.092           1.432
# Armenia                    134.0           0.850           1.055
# ...                          ...             ...             ...
# Venezuela                   29.0           0.960           1.427
# Vietnam                     19.0           0.741           1.346
# Yemen                        5.0           0.287           1.163
# Zambia                       9.0           0.578           1.058
# Zimbabwe                     8.0           0.366           1.114
#
#              Healthy life expectancy  Freedom to make life choices
# Afghanistan                    0.361                         0.000
# ...

# %%
x=data["max_infected_counts"]
y=data["GDP per capita"]

# %%
x
# Out:
# Afghanistan    232.0
# Albania         34.0
# Algeria        199.0
# Argentina      291.0
# Armenia        134.0
#                ...
# Venezuela       29.0
# Vietnam         19.0
# Yemen            5.0
# Zambia           9.0
# Zimbabwe         8.0
# Name: max_infected_counts, Length: 143, dtype: float64

# %%
y
# Out:
# Afghanistan    0.350
# Albania        0.947
# Algeria        1.002
# Argentina      1.092
# Armenia        0.850
#                ...
# Venezuela      0.960
# Vietnam        0.741
# Yemen          0.287
# Zambia         0.578
# Zimbabwe       0.366
# Name: GDP per capita, Length: 143, dtype: float64

# %%
x=data["Social support"]
y=data["max_infected_counts"]
x_log=np.log(x)
y_log=np.log(y)
sns.scatterplot(x=x,y=y_log)
# Out:
# C:\ProgramData\anaconda3\lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# <Axes: xlabel='Social support', ylabel='max_infected_counts'>

# %%
sns.regplot(x=x,y=y)
# Out:
# <Axes: xlabel='Social support', ylabel='GDP per capita'>

# %%
x=data["max_infected_counts"]
y=data["GDP per capita"]
x_log=np.log(x)
y_log=np.log(y)
sns.scatterplot(x=y,y=x_log)
# Out:
# C:\ProgramData\anaconda3\lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# <Axes: xlabel='GDP per capita', ylabel='max_infected_counts'>

# %%
sns.regplot(x=y,y=x_log)
# Out:
# <Axes: xlabel='GDP per capita', ylabel='max_infected_counts'>

# %%
x=data["Healthy life expectancy"]
y=data["max_infected_counts"]
x_log=np.log(x)
y_log=np.log(y)
sns.scatterplot(x=x,y=y_log)
# Out:
# <Axes: xlabel='Healthy life expectancy', ylabel='max_infected_counts'>

# %%
sns.regplot(x=x,y=y_log)
# Out:
# <Axes: xlabel='Healthy life expectancy', ylabel='max_infected_counts'>
